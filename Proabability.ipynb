# %%
import numpy as np
import random

#function for rolling the dice

def roll_the_dice(n_simulations = 100000):
    count = 0
    #each iteration for loop is the trail
    for i in range(n_simulations):
        die1 = random.randint(1,6)
        die2 = random.randint(1,6)
        
        #sum th values to get the score
        score = die1 + die2
        
        #decide if we should add it to the count
        if ((score % 2 ==0 ) or (score > 7)):
            count +=1
            
    return count/n_simulations

string = 'The probability of getting more than 7 is:'
print (string,np.round(roll_the_dice()*100,2),'%')
# Out:
# The probability of getting more than 7 is: 66.65 %

# %%
#A box contains 12 transitors of type A and type 18 of type 8
#one transitor is taken out at random and returned
#this process is repeated
#determine the probablity that the first chosen is type A  and second is type B

import random
trials = 10000 #total number of trials
totalA = 12 #total number of transitorsA
totalB = 18 #total number of transitorsB

successes = 0 #variable keeping of how many succecssful pulls ther are

choicelist = list("A"*totalA+"B"*totalB)

def transistor():
    return random.choice(choicelist)

for i in range(trials):
    try1 = transistor()
    try2= transistor()
    if try1 == 'A'and try2 ==

# %%
n , p = 10, .5
s = np.random.binomial(n,p,1000)
print (s)
# Out:
# [5 6 5 8 3 5 7 3 5 8 4 7 6 6 4 5 4 4 5 5 6 4 7 6 6 5 4 6 4 6 8 2 6 9 3 8 6
#  6 6 8 6 8 3 7 4 5 5 3 6 6 3 3 6 6 6 2 5 6 5 6 4 3 7 4 5 5 4 7 5 4 6 8 2 6
#  6 4 4 6 3 5 4 3 5 6 4 3 7 5 7 4 5 4 7 4 3 6 4 4 5 5 7 3 3 4 4 5 6 7 3 6 6
#  3 3 4 7 6 3 5 4 4 8 7 4 5 3 2 6 8 2 6 8 4 3 5 5 7 9 7 5 4 6 7 5 6 7 5 7 5
#  3 6 5 5 6 4 5 4 4 4 6 8 5 7 4 3 5 6 4 2 7 4 2 2 5 3 7 8 7 7 2 5 5 3 5 4 5
#  3 7 3 2 4 6 5 7 7 3 2 2 8 5 6 5 6 6 7 6 7 1 4 4 5 8 7 4 5 5 5 4 3 4 2 5 6
#  5 9 3 8 7 4 5 6 5 5 2 4 6 4 3 5 2 4 5 8 5 6 6 8 5 5 5 5 5 5 5 4 6 6 8 5 5
#  5 6 5 5 4 5 7 3 4 5 5 4 4 4 3 7 3 6 6 7 4 5 3 5 4 4 5 6 8 7 2 6 6 3 5 6 5
#  5 4 6 4 5 4 6 3 8 6 3 5 3 8 5 2 6 6 4 6 8 4 6 4 4 8 5 5 5 4 5 5 5 4 5 6 6
#  6 8 7 6 2 3 2 3 6 7 6 4 4 4 4 6 9 4 4 5 5 5 4 4 6 6 6 5 2 6 6 6 5 5 4 6 8
#  8 5 7 6 5 3 4 2 5 3 4 3 6 5 7 6 5 4 5 5 7 6 5 5 6 4 6 3 7 9 5 6 1 6 6 6 5
#  4 6 4 2 5 6 5 4 5 4 4 7 4 8 7 6 5 6 3 6 4 5 4 2 5 7 4 3 7 2 3 7 3 2 8 5 5
# ...

# %%
sum(np.random.binomial(9,0.1,20000)==0)/20000
# Out:
# 0.3853

# %%
import seaborn as sns
from scipy.stats import binom
import matplotlib.pyplot as plt

binom.rvs(n=10,p=0.5)
binom.rvs(size=5, n=10, p=0.5)

data_binom=binom.rvs(n=10,p=0.5, size=10000)
ax= sns.distplot(data_binom, kde= True, color= 'skyblue', hist_kws={"linewidth":15, 'alpha':1})
ax.set(xlabel='Binomial', ylabel= 'Frequency')
plt.show()

# %%
from scipy.stats import poisson
import matplotlib.pyplot as plt
plt.ylabel('Probability of car passing')
plt.xlabel('Number of cars')
plt.title('Probability Distribution Curve')
arr= []
rv = poisson(25) #lambda
for num in range(0,40):
    arr.append(rv.pmf(num))
    
prob = rv.pmf(28)
print (prob)
plt.grid(True)
plt.plot(arr, linewidth =2.0)
plt.plot([28],[prob],marker= 'o', markersize=6, color="red")
plt.show()
# Out:
# 0.06321459690112517
