# %% [markdown]
# # EDA 31.07.21 - Life Expectancy

# %% [markdown]
# # Python Project – Life Expectancy
#
# ## Business Case:
#
# The Global Health Observatory (GHO) data repository under World Health Organization (WHO) keeps track of the health status as well as many other related factors for all countries. The data-set related to life expectancy, health factors for 193 countries has been collected from the same WHO data repository website and its corresponding economic data was collected from the United Nation website.  It has been observed that in the past 15 years, there has been a huge development in the health sector resulting in improvement of human mortality rates especially in the developing nations in comparison to the past 30 years.
# WHO has vast data for various verticals that can help humans to strive and survive under extreme conditions. You have been hired as a Data Analyst to  find the hidden key insights that can solve critical questions and provide a solution.
#
#
# ## Problem Statement:
#
#
# Health plays a vital role in deciding the Life Expectancy. People all over the world pay a lot to insurance companies to secure the finance, if there is a health emergency.  It becomes very important to know how much countries are spending on health facilities out of the total expenses.
# Your role is to draw insights on the countries and their expenses pattern.
# What are the health conditions in the country that are spending more or less on the health facilities?
# These solutions can play a critical role in regards to human survival.
# Through the chain of scenarios designed, you will be able to solve problems and follow the process that real Data Analysts perform.

# %% [markdown]
# ## Dataset Description:
# 1.	countryData – file showing the metrics of the country with important parameters.
# 2.	immunitizationData – file showing sickness factors of the country.
#
#
# #### countryData
#
# Column Name	Data Type	Description
# Country	Categorical	 Country name
# Year	Discrete	 Year
# Status	Categorical	 Status of the given country (Either Developing or Developed)
# Life expectancy	Continuous	 in years
# Adult Mortality	Continuous	 Adult Mortality Rates of both sexes (probability of dying between 15 and 60 years per 1000 population)
# Alcohol	Continuous	 Alcohol, recorded per capita (15+) consumption (in litres of pure alcohol)
# Percentage expenditure	Continuous	 Expenditure on health as a percentage of Gross Domestic Product per capita (%)
# Total expenditure	Continuous	 General government expenditure on health as a percentage of total government expenditure (%)
# GDP	Continuous	 Gross Domestic Product per capita (in USD)
# Population	Continuous	 Population of the country
# thinness 1 - 19 years	Continuous	 Prevalence of thinness among children and adolescents for Age 10 to 19 (% )
# thinness 5 - 9 years	Continuous	 Prevalence of thinness among children for Age 5 to 9(%)
# Income composition of resources	Continuous	 Human Development Index in terms of income composition of resources (index ranging from 0 to 1)
# Schooling	Continuous	 Number of years of Schooling(years)
#
# #### immunitizationData
#
# Column Name	Data Type	Description
# Country	Categorical	 Country name
# Year	Discrete	 Year
# Infant deaths	Continuous	 Number of Infant Deaths per 1000 population
# Hepatitis B	Continuous	 Hepatitis B (HepB) immunization coverage among 1 - year olds (%)
# Measles	Continuous	 Measles  number of reported cases per 1000 population
# BMI	Continuous	 Average Body Mass Index of entire population
# Under five death	Continuous	 Number of under - five deaths per 1000 population
# Polio	Continuous	 Polio (Pol3) immunization coverage among 1 - year olds (%)
# Diphtheria	Continuous	 Diphtheria tetanus toxoid and pertussis (DTP3) immunization coverage among 1 - year olds (%)
# HIV/AID	Continuous	 Deaths per 1 000 live births HIV/AIDS (0 - 4 years)

# %% [markdown]
# # Scenario 1:
# You have been given the required dataset by the WHO to help the countries know about their health status, as well as, help individuals to get prepared with the upcoming problems. There are 2 datasets available which are present in csv format and you have to explore it, align it if it is not in structured format.
#
# **Task 1:**
#
# ●	Import the libraries numpy, pandas, Matplotlib and seaborn that are going to be used for data exploration.
#
# ●	Call the two datasets using python and save them under the variable name df1 for “countryData” and df2 for “immunitizationData”.
#
# ●	View the top 3 rows of both datasets.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("countryData.csv")
df2 = pd.read_csv("immunitizationData.csv")

# %%
df1.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  Alcohol  \
# 0  Afghanistan  2015  Developing              65.0            263.0     0.01
# 1  Afghanistan  2014  Developing              59.9            271.0     0.01
# 2  Afghanistan  2013  Developing              59.9            268.0     0.01
# 3  Afghanistan  2012  Developing              59.5            272.0     0.01
# 4  Afghanistan  2011  Developing              59.2            275.0     0.01
#
#    percentage expenditure  Total expenditure         GDP  Population  \
# 0               71.279624               8.16  584.259210  33736494.0
# 1               73.523582               8.18  612.696514    327582.0
# 2               73.219243               8.13  631.744976  31731688.0
# 3               78.184215               8.52  669.959000   3696958.0
# 4                7.097109               7.87   63.537231   2978599.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.2                 17.3
# 1                   17.5                 17.5
# 2                   17.7                 17.7
# 3                   17.9                 18.0
# 4                   18.2                 18.2
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
# 3                            0.463        9.8
# 4                            0.454        9.5

# %%
df2.head()
# Out:
#        Country  Year  infant deaths  Hepatitis B  Measles    BMI   \
# 0  Afghanistan  2015             62         65.0      1154   19.1
# 1  Afghanistan  2014             64         62.0       492   18.6
# 2  Afghanistan  2013             66         64.0       430   18.1
# 3  Afghanistan  2012             69         67.0      2787   17.6
# 4  Afghanistan  2011             71         68.0      3013   17.2
#
#    under-five deaths   Polio  Diphtheria    HIV/AIDS
# 0                  83    6.0         65.0        0.1
# 1                  86   58.0         62.0        0.1
# 2                  89   62.0         64.0        0.1
# 3                  93   67.0         67.0        0.1
# 4                  97   68.0         68.0        0.1

# %% [markdown]
# **Task 2:**
#
# When the dataset is loaded successfully, the first and foremost job of a Data Analyst is to get clarity on the structure of the dataset. To get this information we will do basic exploration, follow below steps;
#
# ●	Once the dataset is called, understanding the feature names becomes important. Show the feature names for both the datasets
#
# ●	What are the dimensions for both the dataset?
#
# ●	Considering you have created the datasets. to apply any operation on a feature you need to understand its datatype.
# Show the datatypes of each column?

# %%
df1.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'Alcohol', 'percentage expenditure', 'Total expenditure', 'GDP',
#        'Population', ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['Country', 'Year', 'infant deaths', 'Hepatitis B', 'Measles ', ' BMI ',
#        'under-five deaths ', 'Polio', 'Diphtheria ', ' HIV/AIDS'],
#       dtype='object')

# %%
print(df1.shape)
print(df2.shape)
# Out:
# (2938, 14)
# (2938, 10)

# %%
df1.dtypes
# Out:
# Country                             object
# Year                                 int64
# Status                              object
# Life expectancy                    float64
# Adult Mortality                    float64
# Alcohol                            float64
# percentage expenditure             float64
# Total expenditure                  float64
# GDP                                float64
# Population                         float64
#  thinness  1-19 years              float64
#  thinness 5-9 years                float64
# Income composition of resources    float64
# Schooling                          float64
# dtype: object

# %%
df2.dtypes
# Out:
# Country                object
# Year                    int64
# infant deaths           int64
# Hepatitis B           float64
# Measles                 int64
#  BMI                  float64
# under-five deaths       int64
# Polio                 float64
# Diphtheria            float64
#  HIV/AIDS             float64
# dtype: object

# %% [markdown]
#      Question :
# A lot of health data is available in ‘immunitizationData’, which is taken as df2. how can you view the column names except “Country” and “Year”?
#
# () df2.columns[2]
#
# () df2.columns[ : 2]
#
# () df2.columns[2 : ]
#
# () df2.columns[ : -2]

# %%
df2.columns[2 : ]
# Out:
# Index(['infant deaths', 'Hepatitis B', 'Measles ', ' BMI ',
#        'under-five deaths ', 'Polio', 'Diphtheria ', ' HIV/AIDS'],
#       dtype='object')

# %% [markdown]
# Question:
# You can use a few commands to view the dataset or check for the dimensions. You have to find the code that will show error, if called (df stands for dataframe)?
#
# () df.shape
#
# () df.head()
#
# () df.row
#
# () df.info()

# %%
df1.row
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-e7992fadf1c0> in <module>
# ----> 1 df1.row
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'row'

# %% [markdown]
# **Task 3:**
#
# You have just kick started your exploration and observed that there is not a single column with unique values that can be used to merge the datasets. Also, the column names have blank spaces, which you have to work to correct. You have to create a primary key column for both data frames by using the apply method. Perform below tasks;
#
# ●	Rename the column by removing blank spaces from both the dataset. Apply string strip function on each dataset column.
#
# ●	Create a unique column, named as “UniqueKey”. We will explore unique columns from both the dataset. If not then we will have to create it.

# %%
df3 = df1.copy()

# %%
df3.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'Alcohol', 'percentage expenditure', 'Total expenditure', 'GDP',
#        'Population', ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
df3.rename(columns = {"percentage expenditure" : "%age Expense", 
                     "Life expectancy " : "Life X"}, inplace = True)

# %%
df3['New total'] = df3['Total expenditure'] + df3['%age Expense']

# %%
df3.head()
# Out:
#        Country  Year      Status  Life X  Adult Mortality  Alcohol  \
# 0  Afghanistan  2015  Developing    65.0            263.0     0.01
# 1  Afghanistan  2014  Developing    59.9            271.0     0.01
# 2  Afghanistan  2013  Developing    59.9            268.0     0.01
# 3  Afghanistan  2012  Developing    59.5            272.0     0.01
# 4  Afghanistan  2011  Developing    59.2            275.0     0.01
#
#    %age Expense  Total expenditure         GDP  Population  \
# 0     71.279624               8.16  584.259210  33736494.0
# 1     73.523582               8.18  612.696514    327582.0
# 2     73.219243               8.13  631.744976  31731688.0
# 3     78.184215               8.52  669.959000   3696958.0
# 4      7.097109               7.87   63.537231   2978599.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.2                 17.3
# 1                   17.5                 17.5
# 2                   17.7                 17.7
# 3                   17.9                 18.0
# 4                   18.2                 18.2
#
#    Income composition of resources  Schooling  New total
# 0                            0.479       10.1  79.439624
# 1                            0.476       10.0  81.703582
# 2                            0.470        9.9  81.349243
# 3                            0.463        9.8  86.704215
# 4                            0.454        9.5  14.967109

# %%
df1 = df1.rename(columns = lambda x : x.strip())
df2 = df2.rename(columns = lambda x : x.strip())

# %%
df1.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy', 'Adult Mortality',
#        'Alcohol', 'percentage expenditure', 'Total expenditure', 'GDP',
#        'Population', 'thinness  1-19 years', 'thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['Country', 'Year', 'infant deaths', 'Hepatitis B', 'Measles', 'BMI',
#        'under-five deaths', 'Polio', 'Diphtheria', 'HIV/AIDS'],
#       dtype='object')

# %% [markdown]
# **Task 4:**
#
# Both the datasets have columns “Country” and “Year” as common, so we can drop columns “Country” and “Year” from any dataframe, or else, after merging you will find two columns each related to “Country” and “Year”.
#
# ●	Remove the columns “Country” and “Year” from df2.
#
# ●	Apply Merge operations on the datasets df1 and df2, using the common column “UniqueKey”, to form a single dataset and name it as df.

# %%
df1['Country'].head(3)
# Out:
# 0    Afghanistan
# 1    Afghanistan
# 2    Afghanistan
# Name: Country, dtype: object

# %%
df1['UniqueKey'] = df1.apply(lambda x : x['Country'] + str(x['Year']), axis = 1)
df2['UniqueKey'] = df2.apply(lambda x : x['Country'] + str(x['Year']), axis = 1)

# %%
df1.head(3)
# Out:
#        Country  Year      Status  Life expectancy  Adult Mortality  Alcohol  \
# 0  Afghanistan  2015  Developing             65.0            263.0     0.01
# 1  Afghanistan  2014  Developing             59.9            271.0     0.01
# 2  Afghanistan  2013  Developing             59.9            268.0     0.01
#
#    percentage expenditure  Total expenditure         GDP  Population  \
# 0               71.279624               8.16  584.259210  33736494.0
# 1               73.523582               8.18  612.696514    327582.0
# 2               73.219243               8.13  631.744976  31731688.0
#
#    thinness  1-19 years  thinness 5-9 years  Income composition of resources  \
# 0                  17.2                17.3                            0.479
# 1                  17.5                17.5                            0.476
# 2                  17.7                17.7                            0.470
#
#    Schooling        UniqueKey
# 0       10.1  Afghanistan2015
# 1       10.0  Afghanistan2014
# 2        9.9  Afghanistan2013

# %%
df2.head()
# Out:
#        Country  Year  infant deaths  Hepatitis B  Measles   BMI  \
# 0  Afghanistan  2015             62         65.0     1154  19.1
# 1  Afghanistan  2014             64         62.0      492  18.6
# 2  Afghanistan  2013             66         64.0      430  18.1
# 3  Afghanistan  2012             69         67.0     2787  17.6
# 4  Afghanistan  2011             71         68.0     3013  17.2
#
#    under-five deaths  Polio  Diphtheria  HIV/AIDS        UniqueKey
# 0                 83    6.0        65.0       0.1  Afghanistan2015
# 1                 86   58.0        62.0       0.1  Afghanistan2014
# 2                 89   62.0        64.0       0.1  Afghanistan2013
# 3                 93   67.0        67.0       0.1  Afghanistan2012
# 4                 97   68.0        68.0       0.1  Afghanistan2011

# %%
df1.UniqueKey.value_counts()
# Out:
# Armenia2015                 1
# Syrian Arab Republic2009    1
# Timor-Leste2004             1
# India2005                   1
# Seychelles2014              1
#                            ..
# Zimbabwe2011                1
# Switzerland2002             1
# Lebanon2000                 1
# Togo2002                    1
# Mauritania2005              1
# Name: UniqueKey, Length: 2938, dtype: int64

# %%
df2.UniqueKey.value_counts()
# Out:
# Armenia2015                 1
# Syrian Arab Republic2009    1
# Timor-Leste2004             1
# India2005                   1
# Seychelles2014              1
#                            ..
# Zimbabwe2011                1
# Switzerland2002             1
# Lebanon2000                 1
# Togo2002                    1
# Mauritania2005              1
# Name: UniqueKey, Length: 2938, dtype: int64

# %%
df1.Year.value_counts()
# Out:
# 2013    193
# 2000    183
# 2002    183
# 2004    183
# 2006    183
# 2008    183
# 2010    183
# 2012    183
# 2014    183
# 2001    183
# 2003    183
# 2005    183
# 2007    183
# 2009    183
# 2011    183
# 2015    183
# Name: Year, dtype: int64

# %%
df2.drop(['Country', 'Year'], axis = 1, inplace = True)

# %%
df2.head(2)
# Out:
#    infant deaths  Hepatitis B  Measles   BMI  under-five deaths  Polio  \
# 0             62         65.0     1154  19.1                 83    6.0
# 1             64         62.0      492  18.6                 86   58.0
#
#    Diphtheria  HIV/AIDS        UniqueKey
# 0        65.0       0.1  Afghanistan2015
# 1        62.0       0.1  Afghanistan2014

# %%
df = pd.merge(df1, df2, on = "UniqueKey", how = 'inner')
df.head()
# Out:
#        Country  Year      Status  Life expectancy  Adult Mortality  Alcohol  \
# 0  Afghanistan  2015  Developing             65.0            263.0     0.01
# 1  Afghanistan  2014  Developing             59.9            271.0     0.01
# 2  Afghanistan  2013  Developing             59.9            268.0     0.01
# 3  Afghanistan  2012  Developing             59.5            272.0     0.01
# 4  Afghanistan  2011  Developing             59.2            275.0     0.01
#
#    percentage expenditure  Total expenditure         GDP  Population  ...  \
# 0               71.279624               8.16  584.259210  33736494.0  ...
# 1               73.523582               8.18  612.696514    327582.0  ...
# 2               73.219243               8.13  631.744976  31731688.0  ...
# 3               78.184215               8.52  669.959000   3696958.0  ...
# 4                7.097109               7.87   63.537231   2978599.0  ...
#
#    Schooling        UniqueKey  infant deaths  Hepatitis B Measles   BMI  \
# 0       10.1  Afghanistan2015             62         65.0    1154  19.1
# 1       10.0  Afghanistan2014             64         62.0     492  18.6
# 2        9.9  Afghanistan2013             66         64.0     430  18.1
# 3        9.8  Afghanistan2012             69         67.0    2787  17.6
# 4        9.5  Afghanistan2011             71         68.0    3013  17.2
#
#    under-five deaths  Polio  Diphtheria  HIV/AIDS
# 0                 83    6.0        65.0       0.1
# 1                 86   58.0        62.0       0.1
# 2                 89   62.0        64.0       0.1
# 3                 93   67.0        67.0       0.1
# 4                 97   68.0        68.0       0.1
#
# [5 rows x 23 columns]

# %%
# drop column Unique Key : YOUR CHOICE

# %% [markdown]
# Question:
# Depending on the various options we have for joins, which one will you prefer ?
#
# () left
#
# () right
#
# () outer
#
# () all of them

# %%
new_ = pd.merge(df1, df2, on = "UniqueKey", how = 'inner')
print(new_.shape)

new_ = pd.merge(df1, df2, on = "UniqueKey", how = 'outer')
print(new_.shape)

new_ = pd.merge(df1, df2, on = "UniqueKey", how = 'left')
print(new_.shape)

new_ = pd.merge(df1, df2, on = "UniqueKey", how = 'right')
print(new_.shape)
# Out:
# (2938, 23)
# (2938, 23)
# (2938, 23)
# (2938, 23)

# %% [markdown]
# # Scenario 2:
#
# You should give yourself a pat. You have successfully merged the dataset . Before you can start exploring the relationships and draw insights, cleaning the dataset is the most important job. Complete below tasks to prepare your dataset for further analysis.

# %% [markdown]
# **Task 1:**
#
# ●	there can be a chance you have received a dataset with duplicate values. Remove them and analyze the dimension of the dataframe before and after removing.
#
# ●	For each feature, identify the total number of unique values.
#
# ●	Information for the feature ‘Uniquekey’ is already reflected in “Country” and “Year”. you can remove it and verify your results by viewing the column names.

# %%
print(df.shape)

df.drop_duplicates(inplace = True)

print(df.shape)
# Out:
# (2938, 23)
# (2938, 23)

# %%
df.nunique()
# Out:
# Country                             193
# Year                                 16
# Status                                2
# Life expectancy                     362
# Adult Mortality                     425
# Alcohol                            1076
# percentage expenditure             2328
# Total expenditure                   818
# GDP                                2490
# Population                         2278
# thinness  1-19 years                200
# thinness 5-9 years                  207
# Income composition of resources     625
# Schooling                           173
# UniqueKey                          2938
# infant deaths                       209
# Hepatitis B                          87
# Measles                             958
# BMI                                 608
# under-five deaths                   252
# Polio                                73
# Diphtheria                           81
# HIV/AIDS                            200
# dtype: int64

# %% [markdown]
# Question:
# What is the total number of unique values present in the “Schooling” feature?

# %% [markdown]
# **Task 2:**
#
# ●	show the total null (NA) values in each feature of the dataset.
#
# ●	Fill NA values in each continuous column by its median. Follow below steps mentioned in the picture attached  .
#
# ●	Check if NAs are present after the above imputing task.

# %%
df.dtypes
# Out:
# Country                             object
# Year                                 int64
# Status                              object
# Life expectancy                    float64
# Adult Mortality                    float64
# Alcohol                            float64
# percentage expenditure             float64
# Total expenditure                  float64
# GDP                                float64
# Population                         float64
# thinness  1-19 years               float64
# thinness 5-9 years                 float64
# Income composition of resources    float64
# Schooling                          float64
# UniqueKey                           object
# infant deaths                        int64
# Hepatitis B                        float64
# Measles                              int64
# BMI                                float64
# under-five deaths                    int64
# Polio                              float64
# Diphtheria                         float64
# HIV/AIDS                           float64
# dtype: object

# %%
df.isna().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# Alcohol                            194
# percentage expenditure               0
# Total expenditure                  226
# GDP                                448
# Population                         652
# thinness  1-19 years                34
# thinness 5-9 years                  34
# Income composition of resources    167
# Schooling                          163
# UniqueKey                            0
# infant deaths                        0
# Hepatitis B                        553
# Measles                              0
# BMI                                 34
# under-five deaths                    0
# Polio                               19
# Diphtheria                          19
# HIV/AIDS                             0
# dtype: int64

# %% [markdown]
# Question:
#
#     There are NAs present in few features of the dataset. Identify the total number of features that have NAs?
#
# () 17
#
# () 15
#
# () 14
#
# () 10
#
# ans = 14

# %% [markdown]
# Question:
#
# You have found a lot of columns with NAs. The count of NAs in each column is not that much to remove the feature. You can apply a function to fill NAs with a central tendency such that the datatype doesn’t change. Which method can you choose?
#
# () Mode
#
# () Mean
#
# () Median
#
# () Max

# %%
df.drop("UniqueKey", axis = 1, inplace = True)

# %%
df.dtypes
# Out:
# Country                             object
# Year                                 int64
# Status                              object
# Life expectancy                    float64
# Adult Mortality                    float64
# Alcohol                            float64
# percentage expenditure             float64
# Total expenditure                  float64
# GDP                                float64
# Population                         float64
# thinness  1-19 years               float64
# thinness 5-9 years                 float64
# Income composition of resources    float64
# Schooling                          float64
# infant deaths                        int64
# Hepatitis B                        float64
# Measles                              int64
# BMI                                float64
# under-five deaths                    int64
# Polio                              float64
# Diphtheria                         float64
# HIV/AIDS                           float64
# dtype: object

# %%
# df['Schooling'].fillna()

# %%
for i in range(3, len(df.columns)) :
    df.iloc[:, i].fillna(df.iloc[: , i].median(), inplace = True)

# %%
# df.iloc[: , 3]

# %%
df.isna().sum()
# Out:
# Country                            0
# Year                               0
# Status                             0
# Life expectancy                    0
# Adult Mortality                    0
# Alcohol                            0
# percentage expenditure             0
# Total expenditure                  0
# GDP                                0
# Population                         0
# thinness  1-19 years               0
# thinness 5-9 years                 0
# Income composition of resources    0
# Schooling                          0
# infant deaths                      0
# Hepatitis B                        0
# Measles                            0
# BMI                                0
# under-five deaths                  0
# Polio                              0
# Diphtheria                         0
# HIV/AIDS                           0
# dtype: int64

# %%
#Scenario case 3
#analysis single colums at a time- univariat analysis

# %%
plt.hist(df['Life expectancy'])
plt.xlabel('Life expectancy')
plt.ylabel("Frequency")
plt.title('Life Distribution')
plt.show()

# %%
df.groupby("Status").mean()
# df.groupby("Status").mean().plot(kind = 'pie', y ="Life expectancy")
# Out:
#                    Year  Life expectancy  Adult Mortality   Alcohol  \
# Status
# Developed   2007.500000        79.197852        79.685547  9.494687
# Developing  2007.522671        67.132028       182.673124  3.502655
#
#             percentage expenditure  Total expenditure           GDP  \
# Status
# Developed              2703.600380           7.441602  19517.581590
# Developing              323.470285           5.603833   3887.739215
#
#               Population  thinness  1-19 years  thinness 5-9 years  \
# Status
# Developed   5.809395e+06              1.320703            1.296680
# Developing  1.116399e+07              5.560800            5.602514
#
#             Income composition of resources  Schooling  infant deaths  \
# Status
# Developed                          0.836037  15.513086       1.494141
# Developing                         0.586955  11.270486      36.384171
#
#             Hepatitis B      Measles        BMI  under-five deaths      Polio  \
# Status
# Developed     89.378906   499.005859  51.803906           1.810547  93.736328
# Developing    81.680544  2824.926216  35.548351          50.525144  80.271228
#
#             Diphtheria  HIV/AIDS
# Status
# Developed    93.476562  0.100000
# Developing   80.053998  2.088664

# %%
df.groupby("Status").mean().plot(kind = 'pie', y ="Life expectancy")
# Out:
# <AxesSubplot:ylabel='Life expectancy'>

# %%
df.groupby("Status").median()['GDP']
# Out:
# Status
# Developed     8477.325445
# Developing    1766.947595
# Name: GDP, dtype: float64

# %%
#show distrubution os status using seaborn, showin each of record 
sns.countplot(df['Status'])
# Out:
# C:\Users\sudeep\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Status', ylabel='count'>

# %%
# Task 4A
# two columns at a time- multivariate analysi

# %%
sns.lineplot(df['Year'], df['Total expenditure'], marker ="o")
# Out:
# C:\Users\sudeep\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Year', ylabel='Total expenditure'>

# %%
sns.lineplot(df['Year'], df['Life expectancy'], marker ="o")
# Out:
# C:\Users\sudeep\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Year', ylabel='Life expectancy'>

# %%
#sns.pairplot(df) compare the features of life expectancy and schooling

# %%
plt.scatter(df['Life expectancy'], df['Schooling'])
# plt.xlabel('Life expectancy')
# plt.ylabel('Life expectancy')

# %%
sns.barplot(x= df['Status'], y= df['Life expectancy'])
# Out:
# <AxesSubplot:xlabel='Status', ylabel='Life expectancy'>

# %%
sns.lineplot(df['Year'],df['HIV/AIDS'])
# Out:
# C:\Users\sudeep\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Year', ylabel='HIV/AIDS'>

# %%
Hepatitis B                        float64
Measles                              int64
BMI                                float64
under-five deaths                    int64
Polio                              float64
Diphtheria                         float64
HIV/AIDS

# %%
#correlation
from matplotlib import rcParams
plt.figure(figsize =(10,8))
sns.heatmap(df.corr(),annot = True)
# Out:
# <AxesSubplot:>

# %%
# Scenario 4

df.describe()
# Out:
#               Year  Life expectancy  Adult Mortality      Alcohol  \
# count  2938.000000      2938.000000      2938.000000  2938.000000
# mean   2007.518720        69.234717       164.725664     4.546875
# std       4.613841         9.509115       124.086215     3.921946
# min    2000.000000        36.300000         1.000000     0.010000
# 25%    2004.000000        63.200000        74.000000     1.092500
# 50%    2008.000000        72.100000       144.000000     3.755000
# 75%    2012.000000        75.600000       227.000000     7.390000
# max    2015.000000        89.000000       723.000000    17.870000
#
#        percentage expenditure  Total expenditure            GDP    Population  \
# count             2938.000000        2938.000000    2938.000000  2.938000e+03
# mean               738.251295           5.924098    6611.523863  1.023085e+07
# std               1987.914858           2.400770   13296.603449  5.402242e+07
# min                  0.000000           0.370000       1.681350  3.400000e+01
# 25%                  4.685343           4.370000     580.486996  4.189172e+05
# 50%                 64.912906           5.755000    1766.947595  1.386542e+06
# 75%                441.534144           7.330000    4779.405190  4.584371e+06
# max              19479.911610          17.600000  119172.741800  1.293859e+09
#
#        thinness  1-19 years  thinness 5-9 years  \
# count           2938.000000         2938.000000
# mean               4.821886            4.852144
# std                4.397621            4.485854
# min                0.100000            0.100000
# 25%                1.600000            1.600000
# 50%                3.300000            3.300000
# 75%                7.100000            7.200000
# max               27.700000           28.600000
#
#        Income composition of resources    Schooling  infant deaths  \
# count                      2938.000000  2938.000000    2938.000000
# mean                          0.630362    12.009837      30.303948
# std                           0.205140     3.265139     117.926501
# min                           0.000000     0.000000       0.000000
# 25%                           0.504250    10.300000       0.000000
# 50%                           0.677000    12.300000       3.000000
# 75%                           0.772000    14.100000      22.000000
# max                           0.948000    20.700000    1800.000000
#
#        Hepatitis B        Measles          BMI  under-five deaths  \
# count  2938.000000    2938.000000  2938.000000        2938.000000
# mean     83.022124    2419.592240    38.381178          42.035739
# std      22.996984   11467.272489    19.935375         160.445548
# min       1.000000       0.000000     1.000000           0.000000
# 25%      82.000000       0.000000    19.400000           0.000000
# 50%      92.000000      17.000000    43.500000           4.000000
# 75%      96.000000     360.250000    56.100000          28.000000
# max      99.000000  212183.000000    87.300000        2500.000000
#
#              Polio   Diphtheria     HIV/AIDS
# count  2938.000000  2938.000000  2938.000000
# mean     82.617767    82.393125     1.742103
# std      23.367166    23.655562     5.077785
# min       3.000000     2.000000     0.100000
# 25%      78.000000    78.000000     0.100000
# 50%      93.000000    93.000000     0.100000
# 75%      97.000000    97.000000     0.800000
# max      99.000000    99.000000    50.600000

# %%
df[df['BMI']==df['BMI'].min()]['Country']
# Out:
# 2887    Viet Nam
# Name: Country, dtype: object

# %%
df[df['Alcohol']==df['Alcohol'].max()]['Country']
# Out:
# 874    Estonia
# Name: Country, dtype: object

# %%
df[df['Life expectancy']==df['Life expectancy'].max()]
# Out:
#           Country  Year      Status  Life expectancy  Adult Mortality  \
# 241       Belgium  2014   Developed             89.0             76.0
# 915       Finland  2014  Developing             89.0             78.0
# 937        France  2008  Developing             89.0             88.0
# 938        France  2007  Developing             89.0             89.0
# 995       Germany  2014   Developed             89.0             69.0
# 1293        Italy  2004   Developed             89.0             66.0
# 1850  New Zealand  2010   Developed             89.0             71.0
# 1916       Norway  2009   Developed             89.0             67.0
# 2056     Portugal  2014   Developed             89.0             78.0
# 2433        Spain  2007   Developed             89.0             72.0
# 2513       Sweden  2007   Developed             89.0             63.0
#
#       Alcohol  percentage expenditure  Total expenditure          GDP  \
# 241     12.60             7163.348923               1.59  47439.39684
# 915      8.80             6164.455402               9.68  49914.61864
# 937     11.90             7002.785925               1.57  45413.65710
# 938     12.20               64.737149               1.45    416.58397
# 995     11.03              941.756291              11.30   4792.65288
# 1293     8.98             4270.914882               8.49  31174.56118
# 1850     9.62             6664.148708              11.20  33691.34837
# 1916     6.68              142.374943               9.49    817.77681
# 2056     9.88              271.254553               9.50   2277.53613
# 2433    11.05              510.932701               8.36   3279.41400
# 2513     6.90             7593.391622               8.92  53324.37937
#
#       Population  ...  Income composition of resources  Schooling  \
# 241     112957.0  ...                            0.890       16.3
# 915    5461512.0  ...                            0.890       17.0
# 937    6437499.0  ...                            0.877       16.1
# 938    6416229.0  ...                            0.873       16.1
# 995      89825.0  ...                            0.920       17.0
# 1293  57685327.0  ...                            0.846       15.6
# 1850   1386542.0  ...                            0.899       20.3
# 1916   4828726.0  ...                            0.936       17.4
# 2056     14162.0  ...                            0.837       16.8
# 2433   4522683.0  ...                            0.849       16.0
# 2513    914892.0  ...                            0.895       15.8
#
#       infant deaths  Hepatitis B  Measles   BMI  under-five deaths  Polio  \
# 241               0         98.0       70  63.4                  1   99.0
# 915               0         92.0        0  61.7                  0   98.0
# 937               3         47.0      604  59.1                  3   98.0
# 938               3         42.0       39  58.6                  3   99.0
# 995               2         88.0      443  61.9                  3   94.0
# 1293              2         96.0      599  57.6                  3   97.0
# 1850              0          9.0       43  64.8                  0   93.0
# 1916              0         92.0        2  58.5                  0   94.0
# 2056              0         98.0        0   6.9                  0   98.0
# 2433              2         96.0      267  61.7                  2   96.0
# 2513              0         92.0        1  56.1                  0   98.0
#
#       Diphtheria  HIV/AIDS
# 241         99.0       0.1
# 915         98.0       0.1
# 937         98.0       0.1
# 938         98.0       0.1
# 995         95.0       0.1
# 1293        94.0       0.1
# 1850        93.0       0.1
# 1916        94.0       0.1
# 2056        98.0       0.1
# 2433        96.0       0.1
# 2513        98.0       0.1
#
# [11 rows x 22 columns]

# %%
#Sceniaor 4

df.groupby('Status').sum()
# Out:
#                Year  Life expectancy  Adult Mortality  Alcohol  \
# Status
# Developed   1027840          40549.3          40799.0  4861.28
# Developing  4870250         162862.3         443165.0  8497.44
#
#             percentage expenditure  Total expenditure           GDP  \
# Status
# Developed             1.384243e+06             3810.1  9.993002e+06
# Developing            7.847389e+05            13594.9  9.431655e+06
#
#               Population  thinness  1-19 years  thinness 5-9 years  \
# Status
# Developed   2.974410e+09                 676.2               663.9
# Developing  2.708383e+10               13490.5             13591.7
#
#             Income composition of resources  Schooling  infant deaths  \
# Status
# Developed                           428.051     7942.7            765
# Developing                         1423.952    27342.2          88268
#
#             Hepatitis B  Measles      BMI  under-five deaths     Polio  \
# Status
# Developed       45762.0   255491  26523.6                927   47993.0
# Developing     198157.0  6853271  86240.3             122574  194738.0
#
#             Diphtheria  HIV/AIDS
# Status
# Developed      47860.0      51.2
# Developing    194211.0    5067.1

# %%
df.groupby('Status').sum()['GDP']
# Out:
# Status
# Developed     9.993002e+06
# Developing    9.431655e+06
# Name: GDP, dtype: float64

# %%
df.groupby('Year').sum()['infant deaths']
# Out:
# Year
# 2000    6870
# 2001    6739
# 2002    6512
# 2003    6382
# 2004    6157
# 2005    5923
# 2006    5821
# 2007    5602
# 2008    5411
# 2009    5299
# 2010    5111
# 2011    4910
# 2012    4820
# 2013    4626
# 2014    4494
# 2015    4356
# Name: infant deaths, dtype: int64

# %%
df.groupby('Year').mean()['Polio']
# Out:
# Year
# 2000    76.551913
# 2001    78.196721
# 2002    79.825137
# 2003    80.491803
# 2004    80.306011
# 2005    81.103825
# 2006    84.573770
# 2007    84.846995
# 2008    85.606557
# 2009    85.371585
# 2010    83.939891
# 2011    84.442623
# 2012    83.939891
# 2013    84.642487
# 2014    84.726776
# 2015    83.207650
# Name: Polio, dtype: float64

# %%
newData = df.loc[(df.Year == 2015) & (df.Population >1000000),:] # :all coluimns or mention the column name
newData.head()
newData.groupby('Status').mean()['Life expectancy']
# Out:
# Status
# Developed     80.330000
# Developing    69.874757
# Name: Life expectancy, dtype: float64

# %%
newData.head(10)
# Out:
#                  Country  Year      Status  Life expectancy  Adult Mortality  \
# 0            Afghanistan  2015  Developing             65.0            263.0
# 32               Algeria  2015  Developing             75.6             19.0
# 48                Angola  2015  Developing             52.4            335.0
# 64   Antigua and Barbuda  2015  Developing             76.4             13.0
# 80             Argentina  2015  Developing             76.3            116.0
# 112            Australia  2015   Developed             82.8             59.0
# 128              Austria  2015   Developed             81.5             65.0
# 144           Azerbaijan  2015  Developing             72.7            118.0
# 160              Bahamas  2015  Developing             76.1            147.0
# 176              Bahrain  2015  Developing             76.9             69.0
#
#      Alcohol  percentage expenditure  Total expenditure           GDP  \
# 0      0.010               71.279624              8.160    584.259210
# 32     3.755                0.000000              5.755   4132.762920
# 48     3.755                0.000000              5.755   3695.793748
# 64     3.755                0.000000              5.755  13566.954100
# 80     3.755                0.000000              5.755  13467.123600
# 112    3.755                0.000000              5.755  56554.387600
# 128    3.755                0.000000              5.755  43665.947000
# 144    3.755                0.000000              5.755     55.313820
# 160    3.755                0.000000              5.755   1766.947595
# 176    3.755                0.000000              5.755  22688.878240
#
#      Population  ...  Income composition of resources  Schooling  \
# 0    33736494.0  ...                            0.479       10.1
# 32   39871528.0  ...                            0.743       14.4
# 48    2785935.0  ...                            0.531       11.4
# 64    1386542.0  ...                            0.784       13.9
# 80   43417765.0  ...                            0.826       17.3
# 112  23789338.0  ...                            0.937       20.4
# 128   8633169.0  ...                            0.892       15.9
# 144   9649341.0  ...                            0.758       12.7
# 160   1386542.0  ...                            0.790       12.6
# 176   1386542.0  ...                            0.823       14.5
#
#      infant deaths  Hepatitis B  Measles   BMI  under-five deaths  Polio  \
# 0               62         65.0     1154  19.1                 83    6.0
# 32              21         95.0       63  59.5                 24   95.0
# 48              66         64.0      118  23.3                 98    7.0
# 64               0         99.0        0  47.7                  0   86.0
# 80               8         94.0        0  62.8                  9   93.0
# 112              1         93.0       74  66.6                  1   93.0
# 128              0         93.0      309  57.6                  0   93.0
# 144              5         96.0        0  52.5                  6   98.0
# 160              0         95.0        0  64.5                  0   95.0
# 176              0         98.0        0  63.6                  0   98.0
#
#      Diphtheria  HIV/AIDS
# 0          65.0       0.1
# 32         95.0       0.1
# 48         64.0       1.9
# 64         99.0       0.2
# 80         94.0       0.1
# 112        93.0       0.1
# 128        93.0       0.1
# 144        96.0       0.1
# 160        95.0       0.1
# 176        98.0       0.1
#
# [10 rows x 22 columns]

# %%
newData.tail(10)
# Out:
#                                                 Country  Year      Status  \
# 2730                                            Ukraine  2015  Developing
# 2746                               United Arab Emirates  2015  Developing
# 2762  United Kingdom of Great Britain and Northern I...  2015   Developed
# 2778                        United Republic of Tanzania  2015  Developing
# 2794                           United States of America  2015   Developed
# 2810                                            Uruguay  2015  Developing
# 2858                 Venezuela (Bolivarian Republic of)  2015  Developing
# 2874                                           Viet Nam  2015  Developing
# 2890                                              Yemen  2015  Developing
# 2922                                           Zimbabwe  2015  Developing
#
#       Life expectancy  Adult Mortality  Alcohol  percentage expenditure  \
# 2730             71.3            195.0    3.755                     0.0
# 2746             77.1             75.0    3.755                     0.0
# 2762             81.2             69.0   10.660                     0.0
# 2778             61.8            279.0    3.755                     0.0
# 2794             79.3             13.0    3.755                     0.0
# 2810             77.0            116.0    3.755                     0.0
# 2858             74.1            157.0    3.755                     0.0
# 2874             76.0            127.0    3.755                     0.0
# 2890             65.7            224.0    3.755                     0.0
# 2922             67.0            336.0    3.755                     0.0
#
#       Total expenditure           GDP  Population  ...  \
# 2730              5.755   2124.662666   4515429.0  ...
# 2746              5.755   3911.746890   1386542.0  ...
# 2762              5.755   1766.947595   1386542.0  ...
# 2778              5.755   1766.947595   1386542.0  ...
# 2794              5.755   1766.947595   1386542.0  ...
# 2810              5.755  15524.842470   3431552.0  ...
# 2858              5.755   1766.947595   1386542.0  ...
# 2874              5.755   1766.947595   1386542.0  ...
# 2890              5.755   1766.947595   1386542.0  ...
# 2922              5.755    118.693830  15777451.0  ...
#
#       Income composition of resources  Schooling  infant deaths  Hepatitis B  \
# 2730                            0.748       15.3              4         22.0
# 2746                            0.836       13.3              1         99.0
# 2762                            0.677       12.3              3         92.0
# 2778                            0.677       12.3             85         98.0
# 2794                            0.677       12.3             23         92.0
# 2810                            0.794       15.5              0         95.0
# 2858                            0.769       14.3              9         87.0
# 2874                            0.678       12.6             28         97.0
# 2890                            0.499        9.0             37         69.0
# 2922                            0.507       10.3             22         87.0
#
#       Measles   BMI  under-five deaths  Polio  Diphtheria  HIV/AIDS
# 2730      105  61.3                  5   51.0        23.0       0.2
# 2746      347  64.2                  1   99.0        99.0       0.1
# 2762       91  66.6                  4   96.0        96.0       0.1
# 2778       30  23.8                119   96.0        98.0       1.4
# 2794      188  69.6                 26   93.0        95.0       0.1
# 2810        0  64.0                  0   95.0        95.0       0.1
# 2858        0  62.1                 10   87.0        87.0       0.1
# 2874      256  17.5                 35   97.0        97.0       0.1
# 2890      468  41.3                 47   63.0        69.0       0.1
# 2922        0  31.8                 32   88.0        87.0       6.2
#
# [10 rows x 22 columns]

# %%
newData.shape
# Out:
# (123, 22)
