# %%
import pandas as pd

# %%
# Selecton and Indexing

# %%
df = pd.read_csv('datasets/citibike_tripdata.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32428 entries, 0 to 32427
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   tripduration         32428 non-null  int64
#  1   starttime            32428 non-null  object
#  2   stoptime             32428 non-null  object
#  3   start station id     32428 non-null  int64
#  4   start station name   32428 non-null  object
#  5   end station id       32428 non-null  int64
#  6   end station name     32428 non-null  object
#  7   bikeid               32428 non-null  int64
#  8   name_localizedValue  32428 non-null  object
#  9   usertype             32428 non-null  object
# dtypes: int64(4), object(6)
# memory usage: 2.5+ MB

# %%
df.describe()
# Out:
#         tripduration  start station id  end station id        bikeid
# count   32428.000000      32428.000000    32428.000000  32428.000000
# mean      798.978352       3264.568829     3255.485568  29817.647959
# std      9961.203954        137.810344      149.390306   2807.705863
# min        61.000000       3183.000000      212.000000  15271.000000
# 25%       236.000000       3192.000000     3186.000000  26310.000000
# 50%       352.000000       3206.000000     3203.000000  29516.000000
# 75%       590.000000       3272.000000     3270.000000  33568.000000
# max    936970.000000       3681.000000     3681.000000  33682.000000

# %%
df.describe(include = 'all')
# Out:
#          tripduration            starttime             stoptime  \
# count    32428.000000                32428                32428
# unique            NaN                31859                31899
# top               NaN  2018-05-03 08:33:24  2018-05-28 15:37:16
# freq              NaN                    3                    3
# mean       798.978352                  NaN                  NaN
# std       9961.203954                  NaN                  NaN
# min         61.000000                  NaN                  NaN
# 25%        236.000000                  NaN                  NaN
# 50%        352.000000                  NaN                  NaN
# 75%        590.000000                  NaN                  NaN
# max     936970.000000                  NaN                  NaN
#
#         start station id start station name  end station id end station name  \
# count       32428.000000              32428    32428.000000            32428
# ...

# %%
df.describe(include = 'object')
# Out:
#                   starttime             stoptime start station name  \
# count                 32428                32428              32428
# unique                31859                31899                 50
# top     2018-05-03 08:33:24  2018-05-28 15:37:16      Grove St PATH
# freq                      3                    3               3313
#
#        end station name name_localizedValue    usertype
# count             32428               32428       32428
# unique               61                  32           2
# top       Grove St PATH   Annual Membership  Subscriber
# freq               4720               20056       30053

# %%
df.head(10)
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           338  2018-05-01 00:04:47  2018-05-01 00:10:25              3639
# 1          1482  2018-05-01 01:31:10  2018-05-01 01:55:53              3681
# 2           232  2018-05-01 01:31:29  2018-05-01 01:35:22              3194
# 3           190  2018-05-01 02:03:29  2018-05-01 02:06:40              3185
# 4           303  2018-05-01 04:27:12  2018-05-01 04:32:16              3207
# 5           176  2018-05-01 04:37:05  2018-05-01 04:40:01              3194
# 6           577  2018-05-01 05:05:46  2018-05-01 05:15:23              3225
# 7           830  2018-05-01 05:11:50  2018-05-01 05:25:41              3207
# 8           395  2018-05-01 05:12:07  2018-05-01 05:18:42              3225
# 9           170  2018-05-01 05:13:52  2018-05-01 05:16:43              3206
#
#       start station name  end station id end station name  bikeid  \
# ...

# %%
df.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           338  2018-05-01 00:04:47  2018-05-01 00:10:25              3639
# 1          1482  2018-05-01 01:31:10  2018-05-01 01:55:53              3681
# 2           232  2018-05-01 01:31:29  2018-05-01 01:35:22              3194
# 3           190  2018-05-01 02:03:29  2018-05-01 02:06:40              3185
# 4           303  2018-05-01 04:27:12  2018-05-01 04:32:16              3207
#
#   start station name  end station id end station name  bikeid  \
# 0         Harborside            3199     Newport Pkwy   33558
# 1           Grand St            3185        City Hall   33593
# 2    McGinley Square            3193     Lincoln Park   29217
# 3          City Hall            3186    Grove St PATH   29662
# 4        Oakland Ave            3195          Sip Ave   15271
#
#                        name_localizedValue    usertype
# 0                        Annual Membership  Subscriber
# ...

# %%
df.tail(8)
# Out:
#        tripduration            starttime             stoptime  \
# 32420           485  2018-05-30 13:44:46  2018-05-30 13:52:51
# 32421           255  2018-05-30 13:45:38  2018-05-30 13:49:54
# 32422           108  2018-05-30 13:49:12  2018-05-30 13:51:00
# 32423           396  2018-05-30 13:49:18  2018-05-30 13:55:55
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32425           316  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
#
#        start station id   start station name  end station id end station name  \
# 32420              3183       Exchange Place            3211       Newark Ave
# 32421              3183       Exchange Place            3213   Van Vorst Park
# 32422              3202         Newport PATH            3199     Newport Pkwy
# 32423              3184          Paulus Hook            3279      Dixon Mills
# ...

# %%
df['stoptime'].head(8)
# Out:
# 0    2018-05-01 00:10:25
# 1    2018-05-01 01:55:53
# 2    2018-05-01 01:35:22
# 3    2018-05-01 02:06:40
# 4    2018-05-01 04:32:16
# 5    2018-05-01 04:40:01
# 6    2018-05-01 05:15:23
# 7    2018-05-01 05:25:41
# Name: stoptime, dtype: object

# %%
# accesing two column
df[['stoptime', 'tripduration']].head()
# Out:
#               stoptime  tripduration
# 0  2018-05-01 00:10:25           338
# 1  2018-05-01 01:55:53          1482
# 2  2018-05-01 01:35:22           232
# 3  2018-05-01 02:06:40           190
# 4  2018-05-01 04:32:16           303

# %%
#### to find the value of intersection of some row and column we use the at() function

# %%
df.at[4, 'tripduration']
# Out:
# 303

# %%
df.at[1 , 'tripduration'] = 482

# %%
df[['stoptime', 'tripduration']].head()
# Out:
#               stoptime  tripduration
# 0  2018-05-01 00:10:25           338
# 1  2018-05-01 01:55:53           482
# 2  2018-05-01 01:35:22           232
# 3  2018-05-01 02:06:40           190
# 4  2018-05-01 04:32:16           303

# %% [markdown]
# # Slicing operations
#
# - slicing op will always give new dataframe

# %% [markdown]
# 1. Normal slicing
# 2. loc
# 3. iloc

# %%
# 1 . normal

# df[row_name_start , : row_name_stop : step]

# - it supports both negative and positive indexing
# - it suporrts the user row name for slicing also

# %%
df
# Out:
#        tripduration            starttime             stoptime  \
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
# 1               482  2018-05-01 01:31:10  2018-05-01 01:55:53
# 2               232  2018-05-01 01:31:29  2018-05-01 01:35:22
# 3               190  2018-05-01 02:03:29  2018-05-01 02:06:40
# 4               303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ...             ...                  ...                  ...
# 32423           396  2018-05-30 13:49:18  2018-05-30 13:55:55
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32425           316  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
#
#        start station id   start station name  end station id end station name  \
# 0                  3639           Harborside            3199     Newport Pkwy
# ...

# %%
df[0:6]
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           338  2018-05-01 00:04:47  2018-05-01 00:10:25              3639
# 1           482  2018-05-01 01:31:10  2018-05-01 01:55:53              3681
# 2           232  2018-05-01 01:31:29  2018-05-01 01:35:22              3194
# 3           190  2018-05-01 02:03:29  2018-05-01 02:06:40              3185
# 4           303  2018-05-01 04:27:12  2018-05-01 04:32:16              3207
# 5           176  2018-05-01 04:37:05  2018-05-01 04:40:01              3194
#
#   start station name  end station id end station name  bikeid  \
# 0         Harborside            3199     Newport Pkwy   33558
# 1           Grand St            3185        City Hall   33593
# 2    McGinley Square            3193     Lincoln Park   29217
# 3          City Hall            3186    Grove St PATH   29662
# 4        Oakland Ave            3195          Sip Ave   15271
# ...

# %%
df[::-1]
# Out:
#        tripduration            starttime             stoptime  \
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32425           316  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32423           396  2018-05-30 13:49:18  2018-05-30 13:55:55
# ...             ...                  ...                  ...
# 4               303  2018-05-01 04:27:12  2018-05-01 04:32:16
# 3               190  2018-05-01 02:03:29  2018-05-01 02:06:40
# 2               232  2018-05-01 01:31:29  2018-05-01 01:35:22
# 1               482  2018-05-01 01:31:10  2018-05-01 01:55:53
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
#
#        start station id   start station name  end station id end station name  \
# 32427              3220    5 Corners Library            3207      Oakland Ave
# ...

# %%
df[::2]
# Out:
#        tripduration            starttime             stoptime  \
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
# 2               232  2018-05-01 01:31:29  2018-05-01 01:35:22
# 4               303  2018-05-01 04:27:12  2018-05-01 04:32:16
# 6               577  2018-05-01 05:05:46  2018-05-01 05:15:23
# 8               395  2018-05-01 05:12:07  2018-05-01 05:18:42
# ...             ...                  ...                  ...
# 32418           340  2018-05-30 13:42:45  2018-05-30 13:48:26
# 32420           485  2018-05-30 13:44:46  2018-05-30 13:52:51
# 32422           108  2018-05-30 13:49:12  2018-05-30 13:51:00
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
#
#        start station id     start station name  end station id  \
# 0                  3639             Harborside            3199
# 2                  3194        McGinley Square            3193
# ...

# %%
new_df = df[:6]

idx = ['row_1', 'row_2', 'row_3',
       'row_4', 'row_5', 'row_6']

# %%
new_df.index = idx

# %%
new_df
# Out:
#        tripduration            starttime             stoptime  \
# row_1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# row_2           482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row_3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# row_4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
# row_5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
# row_6           176  2018-05-01 04:37:05  2018-05-01 04:40:01
#
#        start station id start station name  end station id end station name  \
# row_1              3639         Harborside            3199     Newport Pkwy
# row_2              3681           Grand St            3185        City Hall
# row_3              3194    McGinley Square            3193     Lincoln Park
# row_4              3185          City Hall            3186    Grove St PATH
# row_5              3207        Oakland Ave            3195          Sip Ave
# ...

# %%
new_df[::2]
# Out:
#        tripduration            starttime             stoptime  \
# row_1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# row_3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# row_5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
#
#        start station id start station name  end station id end station name  \
# row_1              3639         Harborside            3199     Newport Pkwy
# row_3              3194    McGinley Square            3193     Lincoln Park
# row_5              3207        Oakland Ave            3195          Sip Ave
#
#        bikeid                      name_localizedValue    usertype
# row_1   33558                        Annual Membership  Subscriber
# row_3   29217  FREE Bonus Month with Annual Membership  Subscriber
# row_5   15271                        Annual Membership  Subscriber

# %%
new_df['row_1':'row_3']
# Out:
#        tripduration            starttime             stoptime  \
# row_1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# row_2           482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row_3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
#
#        start station id start station name  end station id end station name  \
# row_1              3639         Harborside            3199     Newport Pkwy
# row_2              3681           Grand St            3185        City Hall
# row_3              3194    McGinley Square            3193     Lincoln Park
#
#        bikeid                      name_localizedValue    usertype
# row_1   33558                        Annual Membership  Subscriber
# row_2   33593                                  24 Hour    Customer
# row_3   29217  FREE Bonus Month with Annual Membership  Subscriber

# %% [markdown]
# # 2. loc method
# #### - it does slicing for rows as well as column
# #### synatx = df.loc[row_index_start: row_index_stop : step , column_index_start: column_index_stop : step]

# %%
new_df.loc['row_2']
# Out:
# tripduration                           482
# starttime              2018-05-01 01:31:10
# stoptime               2018-05-01 01:55:53
# start station id                      3681
# start station name                Grand St
# end station id                        3185
# end station name                 City Hall
# bikeid                               33593
# name_localizedValue                24 Hour
# usertype                          Customer
# Name: row_2, dtype: object

# %%
new_df.loc['row_1':'row_2']
# Out:
#        tripduration            starttime             stoptime  \
# row_1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# row_2           482  2018-05-01 01:31:10  2018-05-01 01:55:53
#
#        start station id start station name  end station id end station name  \
# row_1              3639         Harborside            3199     Newport Pkwy
# row_2              3681           Grand St            3185        City Hall
#
#        bikeid name_localizedValue    usertype
# row_1   33558   Annual Membership  Subscriber
# row_2   33593             24 Hour    Customer

# %%
# slicing the row in reverrse
new_df.loc['row_1':'row_4':-1]
# Out:
# Empty DataFrame
# Columns: [tripduration, starttime, stoptime, start station id, start station name, end station id, end station name, bikeid, name_localizedValue, usertype]
# Index: []

# %%
# slicing the row in reverrse
new_df.loc['row_4':'row_1':-1]
# Out:
#        tripduration            starttime             stoptime  \
# row_4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
# row_3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# row_2           482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row_1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
#
#        start station id start station name  end station id end station name  \
# row_4              3185          City Hall            3186    Grove St PATH
# row_3              3194    McGinley Square            3193     Lincoln Park
# row_2              3681           Grand St            3185        City Hall
# row_1              3639         Harborside            3199     Newport Pkwy
#
#        bikeid                      name_localizedValue    usertype
# row_4   29662                                  24 Hour    Customer
# row_3   29217  FREE Bonus Month with Annual Membership  Subscriber
# row_2   33593                                  24 Hour    Customer
# ...

# %%
#slicing both rows and columns

new_df.loc[:: , "tripduration" : 'stoptime':2]
# Out:
#        tripduration             stoptime
# row_1           338  2018-05-01 00:10:25
# row_2           482  2018-05-01 01:55:53
# row_3           232  2018-05-01 01:35:22
# row_4           190  2018-05-01 02:06:40
# row_5           303  2018-05-01 04:32:16
# row_6           176  2018-05-01 04:40:01

# %%
new_df.loc[['row_1' , 'row_2' , 'row_4'] , ['tripduration'] ]
# Out:
#        tripduration
# row_1           338
# row_2           482
# row_4           190

# %%
# slcing based on some condition

# only those data where trip duration is more than 200
new_df.loc[new_df['tripduration'] > 200]
# Out:
#        tripduration            starttime             stoptime  \
# row_1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# row_2           482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row_3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# row_5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
#
#        start station id start station name  end station id end station name  \
# row_1              3639         Harborside            3199     Newport Pkwy
# row_2              3681           Grand St            3185        City Hall
# row_3              3194    McGinley Square            3193     Lincoln Park
# row_5              3207        Oakland Ave            3195          Sip Ave
#
#        bikeid                      name_localizedValue    usertype
# row_1   33558                        Annual Membership  Subscriber
# row_2   33593                                  24 Hour    Customer
# row_3   29217  FREE Bonus Month with Annual Membership  Subscriber
# ...

# %%
new_df.loc[(new_df['tripduration'] > 200) & (new_df['tripduration'] <300)  , 'tripduration':'bikeid']
# Out:
#        tripduration            starttime             stoptime  \
# row_3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
#
#        start station id start station name  end station id end station name  \
# row_3              3194    McGinley Square            3193     Lincoln Park
#
#        bikeid
# row_3   29217

# %%
(new_df['tripduration'] > 200) & (new_df['tripduration'] <300)
# Out:
# row_1    False
# row_2    False
# row_3     True
# row_4    False
# row_5    False
# row_6    False
# Name: tripduration, dtype: bool

# %%
new_df.loc[new_df['usertype']=='Subscriber']
# Out:
#        tripduration            starttime             stoptime  \
# row_1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# row_3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# row_5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
# row_6           176  2018-05-01 04:37:05  2018-05-01 04:40:01
#
#        start station id start station name  end station id end station name  \
# row_1              3639         Harborside            3199     Newport Pkwy
# row_3              3194    McGinley Square            3193     Lincoln Park
# row_5              3207        Oakland Ave            3195          Sip Ave
# row_6              3194    McGinley Square            3195          Sip Ave
#
#        bikeid                      name_localizedValue    usertype
# row_1   33558                        Annual Membership  Subscriber
# row_3   29217  FREE Bonus Month with Annual Membership  Subscriber
# row_5   15271                        Annual Membership  Subscriber
# ...

# %%
new_df.loc[(new_df['usertype']=='Subscriber') & (new_df['bikeid'] < 30000)]
# Out:
#        tripduration            starttime             stoptime  \
# row_3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# row_5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
# row_6           176  2018-05-01 04:37:05  2018-05-01 04:40:01
#
#        start station id start station name  end station id end station name  \
# row_3              3194    McGinley Square            3193     Lincoln Park
# row_5              3207        Oakland Ave            3195          Sip Ave
# row_6              3194    McGinley Square            3195          Sip Ave
#
#        bikeid                      name_localizedValue    usertype
# row_3   29217  FREE Bonus Month with Annual Membership  Subscriber
# row_5   15271                        Annual Membership  Subscriber
# row_6   29298                        Annual Membership  Subscriber

# %% [markdown]
# # 3. iloc
# - slicng on rows and cloumn but onlu using index
#
# - synatx = df.iloc[start:stop:step , start:stop:step]

# %%
new_df.iloc[0: 3 , 0:5]
# Out:
#        tripduration            starttime             stoptime  \
# row_1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# row_2           482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row_3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
#
#        start station id start station name
# row_1              3639         Harborside
# row_2              3681           Grand St
# row_3              3194    McGinley Square

# %%
# Sorting

df = pd.read_csv('datasets/unsorted_imdb_rating.csv')

# %%
df
# Out:
#    star_rating                                          title      genre  \
# 0          9.3                       The Shawshank Redemption      Crime
# 1          9.1                                  The Godfather      Crime
# 2          9.2                         The Godfather: Part II      Crime
# 3          9.0                                The Dark Knight     Action
# 4          8.9                                   Pulp Fiction      Crime
# 5          8.8                                   12 Angry Men      Drama
# 6          8.7                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.3                               Schindler's List  Biography
# 9          8.1                                     Fight Club      Drama
#
#    duration
# 0       142
# 1       175
# 2       200
# 3       152
# 4       154
# 5        96
# 6       161
# 7       201
# 8       195
# 9       139

# %%
df.index = [8, 9, 5, 4, 7, 1, 2, 0, 3, 6]

# %%
df
# Out:
#    star_rating                                          title      genre  \
# 8          9.3                       The Shawshank Redemption      Crime
# 9          9.1                                  The Godfather      Crime
# 5          9.2                         The Godfather: Part II      Crime
# 4          9.0                                The Dark Knight     Action
# 7          8.9                                   Pulp Fiction      Crime
# 1          8.8                                   12 Angry Men      Drama
# 2          8.7                 The Good, the Bad and the Ugly    Western
# 0          8.9  The Lord of the Rings: The Return of the King  Adventure
# 3          8.3                               Schindler's List  Biography
# 6          8.1                                     Fight Club      Drama
#
#    duration
# 8       142
# 9       175
# 5       200
# 4       152
# 7       154
# 1        96
# 2       161
# 0       201
# 3       195
# 6       139

# %%
df.sort_index()
# Out:
#    star_rating                                          title      genre  \
# 0          8.9  The Lord of the Rings: The Return of the King  Adventure
# 1          8.8                                   12 Angry Men      Drama
# 2          8.7                 The Good, the Bad and the Ugly    Western
# 3          8.3                               Schindler's List  Biography
# 4          9.0                                The Dark Knight     Action
# 5          9.2                         The Godfather: Part II      Crime
# 6          8.1                                     Fight Club      Drama
# 7          8.9                                   Pulp Fiction      Crime
# 8          9.3                       The Shawshank Redemption      Crime
# 9          9.1                                  The Godfather      Crime
#
#    duration
# 0       201
# 1        96
# 2       161
# 3       195
# 4       152
# 5       200
# 6       139
# 7       154
# 8       142
# 9       175

# %%
df.sort_index(ascending=False)
# Out:
#    star_rating                                          title      genre  \
# 9          9.1                                  The Godfather      Crime
# 8          9.3                       The Shawshank Redemption      Crime
# 7          8.9                                   Pulp Fiction      Crime
# 6          8.1                                     Fight Club      Drama
# 5          9.2                         The Godfather: Part II      Crime
# 4          9.0                                The Dark Knight     Action
# 3          8.3                               Schindler's List  Biography
# 2          8.7                 The Good, the Bad and the Ugly    Western
# 1          8.8                                   12 Angry Men      Drama
# 0          8.9  The Lord of the Rings: The Return of the King  Adventure
#
#    duration
# 9       175
# 8       142
# 7       154
# 6       139
# 5       200
# 4       152
# 3       195
# 2       161
# 1        96
# 0       201

# %%
# sort_values

df.sort_values(by='duration')
# Out:
#    star_rating                                          title      genre  \
# 1          8.8                                   12 Angry Men      Drama
# 6          8.1                                     Fight Club      Drama
# 8          9.3                       The Shawshank Redemption      Crime
# 4          9.0                                The Dark Knight     Action
# 7          8.9                                   Pulp Fiction      Crime
# 2          8.7                 The Good, the Bad and the Ugly    Western
# 9          9.1                                  The Godfather      Crime
# 3          8.3                               Schindler's List  Biography
# 5          9.2                         The Godfather: Part II      Crime
# 0          8.9  The Lord of the Rings: The Return of the King  Adventure
#
#    duration
# 1        96
# 6       139
# 8       142
# 4       152
# 7       154
# 2       161
# 9       175
# 3       195
# 5       200
# 0       201

# %%
# i want a data with column ( star_rat , title , genre) where the values will be sorted by genre

df[['star_rating','title','genre']].sort_values(by='genre')
# Out:
#    star_rating                                          title      genre
# 4          9.0                                The Dark Knight     Action
# 0          8.9  The Lord of the Rings: The Return of the King  Adventure
# 3          8.3                               Schindler's List  Biography
# 8          9.3                       The Shawshank Redemption      Crime
# 9          9.1                                  The Godfather      Crime
# 5          9.2                         The Godfather: Part II      Crime
# 7          8.9                                   Pulp Fiction      Crime
# 1          8.8                                   12 Angry Men      Drama
# 6          8.1                                     Fight Club      Drama
# 2          8.7                 The Good, the Bad and the Ugly    Western

# %%
df[['star_rating','title','genre']].sort_values(by=['genre' , 'star_rating'])
# Out:
#    star_rating                                          title      genre
# 4          9.0                                The Dark Knight     Action
# 0          8.9  The Lord of the Rings: The Return of the King  Adventure
# 3          8.3                               Schindler's List  Biography
# 7          8.9                                   Pulp Fiction      Crime
# 9          9.1                                  The Godfather      Crime
# 5          9.2                         The Godfather: Part II      Crime
# 8          9.3                       The Shawshank Redemption      Crime
# 6          8.1                                     Fight Club      Drama
# 1          8.8                                   12 Angry Men      Drama
# 2          8.7                 The Good, the Bad and the Ugly    Western

# %% [markdown]
# # Concatination

# %%
india_weather = pd.DataFrame({
    "city": ["mumbai","delhi","banglore"],
    "temperature": [32,45,30],
    "humidity": [80, 60, 78]
})
india_weather
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78

# %%
us_weather = pd.DataFrame({
    "city": ["new york","chicago","orlando"],
    "temperature": [21,14,35],
    "humidity": [68, 65, 75]
})
us_weather
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
df = pd.concat([india_weather , us_weather])
df
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
# ignore index 
df = pd.concat([india_weather , us_weather] , ignore_index=True)
df
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78
# 3  new york           21        68
# 4   chicago           14        65
# 5   orlando           35        75

# %%
df = pd.concat([india_weather , us_weather], keys=['India' , "us"])
df
# Out:
#              city  temperature  humidity
# India 0    mumbai           32        80
#       1     delhi           45        60
#       2  banglore           30        78
# us    0  new york           21        68
#       1   chicago           14        65
#       2   orlando           35        75

# %%
df.loc['India']
# Out:
#      city  temperature  humidity
# 0  mumbai           32        80

# %%
df.loc['us']
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %% [markdown]
# # concatination using columns

# %%
temperature_df = pd.DataFrame({
    "city": ["mumbai","delhi","banglore"],
    "temperature": [32,45,30],
}, index=[0,1,2])
temperature_df
# Out:
#        city  temperature
# 0    mumbai           32
# 1     delhi           45
# 2  banglore           30

# %%
windspeed_df = pd.DataFrame({
    "city": ["delhi","mumbai"],
    "windspeed": [7,12],
}, index=[1,0])
windspeed_df
# Out:
#      city  windspeed
# 1   delhi          7
# 0  mumbai         12

# %%
df = pd.concat([temperature_df,windspeed_df],axis=1)  # column index
df
# Out:
#        city  temperature    city  windspeed
# 0    mumbai           32  mumbai       12.0
# 1     delhi           45   delhi        7.0
# 2  banglore           30     NaN        NaN

# %%
# Concatination datframes with series

s = pd.Series(["Humid","Dry","Rain"], name = 'event')
s
# Out:
# 0    Humid
# 1      Dry
# 2     Rain
# Name: event, dtype: object

# %%
df = pd.concat([temperature_df,s],axis = 1)

# %%
df
# Out:
#        city  temperature  event
# 0    mumbai           32  Humid
# 1     delhi           45    Dry
# 2  banglore           30   Rain

# %%
# merge

# %%
import pandas as pd
df1 = pd.DataFrame({
    "city": ["new york","chicago","orlando"],
    "temperature": [21,14,35],
})
df1
# Out:
#        city  temperature
# 0  new york           21
# 1   chicago           14
# 2   orlando           35

# %%
df2 = pd.DataFrame({
    "city": ["chicago","new york","london"],
    "humidity": [65,68,75],
})
df2
# Out:
#        city  humidity
# 0   chicago        65
# 1  new york        68
# 2    london        75

# %%
pd.merge(df1 , df2 , how='inner' , on='city' )
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65

# %%
df1 = pd.DataFrame({
    "city": ["new york","chicago","orlando", "baltimore"],
    "temperature": [21,14,35, 38],
})
df1
# Out:
#         city  temperature
# 0   new york           21
# 1    chicago           14
# 2    orlando           35
# 3  baltimore           38

# %%
df2 = pd.DataFrame({
    "city": ["chicago","new york","san diego"],
    "humidity": [65,68,71],
})
df2
# Out:
#         city  humidity
# 0    chicago        65
# 1   new york        68
# 2  san diego        71

# %%
df3=pd.merge(df1,df2,on="city",how="inner")
df3
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65

# %%
df3=pd.merge(df1,df2,on="city",how="outer")
df3
# Out:
#         city  temperature  humidity
# 0   new york         21.0      68.0
# 1    chicago         14.0      65.0
# 2    orlando         35.0       NaN
# 3  baltimore         38.0       NaN
# 4  san diego          NaN      71.0

# %%
df1
# Out:
#         city  temperature
# 0   new york           21
# 1    chicago           14
# 2    orlando           35
# 3  baltimore           38

# %%
df2
# Out:
#         city  humidity
# 0    chicago        65
# 1   new york        68
# 2  san diego        71

# %%
df3=pd.merge(df1,df2,on="city",how="left")
df3
# Out:
#         city  temperature  humidity
# 0   new york           21      68.0
# 1    chicago           14      65.0
# 2    orlando           35       NaN
# 3  baltimore           38       NaN

# %%
df3=pd.merge(df1,df2,on="city",how="right")
df3
# Out:
#         city  temperature  humidity
# 0    chicago         14.0        65
# 1   new york         21.0        68
# 2  san diego          NaN        71

# %%
df3=pd.merge(df1,df2,on="city",how="right" , indicator=True)
df3
# Out:
#         city  temperature  humidity      _merge
# 0    chicago         14.0        65        both
# 1   new york         21.0        68        both
# 2  san diego          NaN        71  right_only

# %% [markdown]
# # handling_misiing_data_fillna_drop_na

# %%
df = pd.read_csv('datasets/weather_data_nan.csv')

# %%
df
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017          NaN        9.0   Sunny
# 2   1/5/2017         28.0        NaN    Snow
# 3   1/6/2017          NaN        7.0     NaN
# 4   1/7/2017         32.0        NaN    Rain
# 5   1/8/2017          NaN        NaN   Sunny
# 6   1/9/2017          NaN        NaN     NaN
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %%
# make day as index

df.set_index('day', inplace = True)

# %%
df
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017           NaN        9.0   Sunny
# 1/5/2017          28.0        NaN    Snow
# 1/6/2017           NaN        7.0     NaN
# 1/7/2017          32.0        NaN    Rain
# 1/8/2017           NaN        NaN   Sunny
# 1/9/2017           NaN        NaN     NaN
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
# fillna
# - Fill all NaN with one specific value

df.fillna(0)
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017           0.0        9.0   Sunny
# 1/5/2017          28.0        0.0    Snow
# 1/6/2017           0.0        7.0       0
# 1/7/2017          32.0        0.0    Rain
# 1/8/2017           0.0        0.0   Sunny
# 1/9/2017           0.0        0.0       0
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
new_df = df.fillna({
        'temperature': 0,
        'windspeed': 0,
        'event': 'No Event'
    })
new_df
# Out:
#            temperature  windspeed     event
# day
# 1/1/2017          32.0        6.0      Rain
# 1/4/2017           0.0        9.0     Sunny
# 1/5/2017          28.0        0.0      Snow
# 1/6/2017           0.0        7.0  No Event
# 1/7/2017          32.0        0.0      Rain
# 1/8/2017           0.0        0.0     Sunny
# 1/9/2017           0.0        0.0  No Event
# 1/10/2017         34.0        8.0    Cloudy
# 1/11/2017         40.0       12.0     Sunny

# %%
new_df = df.fillna({ 'temperature': df['temperature'].mean(), 
                    'windspeed': df['windspeed'].mean(), 
                    'event':  df['event'].mode()[0] })
new_df
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017          33.2        9.0   Sunny
# 1/5/2017          28.0        8.4    Snow
# 1/6/2017          33.2        7.0   Sunny
# 1/7/2017          32.0        8.4    Rain
# 1/8/2017          33.2        8.4   Sunny
# 1/9/2017          33.2        8.4   Sunny
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
 df['event'].mode()[0]
# Out:
# 'Sunny'

# %%
df.fillna(method="ffill")
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017          32.0        9.0   Sunny
# 1/5/2017          28.0        9.0    Snow
# 1/6/2017          28.0        7.0    Snow
# 1/7/2017          32.0        7.0    Rain
# 1/8/2017          32.0        7.0   Sunny
# 1/9/2017          32.0        7.0   Sunny
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
df.fillna(method="bfill")
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017          28.0        9.0   Sunny
# 1/5/2017          28.0        7.0    Snow
# 1/6/2017          32.0        7.0    Rain
# 1/7/2017          32.0        8.0    Rain
# 1/8/2017          34.0        8.0   Sunny
# 1/9/2017          34.0        8.0  Cloudy
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
df.at['1/1/2017' , 'temperature'] = np.nan

# %%
df
# Out:
#                        temperature  windspeed   event
# day
# 1/1/2017                       NaN        6.0    Rain
# 1/4/2017                       NaN        9.0   Sunny
# 1/5/2017                      28.0        NaN    Snow
# 1/6/2017                       NaN        7.0     NaN
# 1/7/2017                      32.0        NaN    Rain
# 1/8/2017                       NaN        NaN   Sunny
# 1/9/2017                       NaN        NaN     NaN
# 1/10/2017                     34.0        8.0  Cloudy
# 1/11/2017                     40.0       12.0   Sunny
# 0                              NaN        NaN     NaN
# 0.0004957858205255329          NaN        NaN     NaN

# %%
df.fillna(method="ffill")
# Out:
#                        temperature  windspeed   event
# day
# 1/1/2017                       NaN        6.0    Rain
# 1/4/2017                       NaN        9.0   Sunny
# 1/5/2017                      28.0        9.0    Snow
# 1/6/2017                      28.0        7.0    Snow
# 1/7/2017                      32.0        7.0    Rain
# 1/8/2017                      32.0        7.0   Sunny
# 1/9/2017                      32.0        7.0   Sunny
# 1/10/2017                     34.0        8.0  Cloudy
# 1/11/2017                     40.0       12.0   Sunny
# 0                             40.0       12.0   Sunny
# 0.0004957858205255329         40.0       12.0   Sunny

# %%
df
# Out:
#                        temperature  windspeed   event
# day
# 1/1/2017                       NaN        6.0    Rain
# 1/4/2017                       NaN        9.0   Sunny
# 1/5/2017                      28.0        NaN    Snow
# 1/6/2017                       NaN        7.0     NaN
# 1/7/2017                      32.0        NaN    Rain
# 1/8/2017                       NaN        NaN   Sunny
# 1/9/2017                       NaN        NaN     NaN
# 1/10/2017                     34.0        8.0  Cloudy
# 1/11/2017                     40.0       12.0   Sunny
# 0                              NaN        NaN     NaN
# 0.0004957858205255329          NaN        NaN     NaN

# %%
# dropna

df.dropna()
# Out:
#            temperature  windspeed   event
# day
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
df.dropna(axis = 1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [1/1/2017, 1/4/2017, 1/5/2017, 1/6/2017, 1/7/2017, 1/8/2017, 1/9/2017, 1/10/2017, 1/11/2017, 0, 0.0004957858205255329]

# %%
# replace

# %%
df = pd.read_csv("datasets/weather_data_replace.csv")

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017       -99999          7  Sunny
# 2  1/3/2017           28     -99999   Snow
# 3  1/4/2017       -99999          7      0
# 4  1/5/2017           32     -99999   Rain
# 5  1/6/2017           31          2  Sunny
# 6  1/6/2017           34          5      0

# %%
# replacinf with a nan value

df.replace(-99999 , value = np.nan)
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/2/2017          NaN        7.0  Sunny
# 2  1/3/2017         28.0        NaN   Snow
# 3  1/4/2017          NaN        7.0      0
# 4  1/5/2017         32.0        NaN   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0      0

# %%
df = df.replace([-99999 , 32] , value = np.nan)

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017          NaN        6.0   Rain
# 1  1/2/2017          NaN        7.0  Sunny
# 2  1/3/2017         28.0        NaN   Snow
# 3  1/4/2017          NaN        7.0      0
# 4  1/5/2017          NaN        NaN   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0      0

# %%
df.replace(np.nan , value = -1)
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         -1.0        6.0   Rain
# 1  1/2/2017         -1.0        7.0  Sunny
# 2  1/3/2017         28.0       -1.0   Snow
# 3  1/4/2017         -1.0        7.0      0
# 4  1/5/2017         -1.0       -1.0   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0      0

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017          NaN        6.0   Rain
# 1  1/2/2017          NaN        7.0  Sunny
# 2  1/3/2017         28.0        NaN   Snow
# 3  1/4/2017          NaN        7.0      0
# 4  1/5/2017          NaN        NaN   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0      0

# %%
new_df = df.replace({
        'temperature': np.nan,
        'windspeed': -6,
        'event': '0'
    }, 'replaced')
new_df
# Out:
#         day temperature  windspeed     event
# 0  1/1/2017    replaced        6.0      Rain
# 1  1/2/2017    replaced        7.0     Sunny
# 2  1/3/2017          28        NaN      Snow
# 3  1/4/2017    replaced        7.0  replaced
# 4  1/5/2017    replaced        NaN      Rain
# 5  1/6/2017          31        2.0     Sunny
# 6  1/6/2017          34        5.0  replaced

# %%
df = pd.DataFrame({
    'score': ['exceptional','average', 'good', 'poor', 'average', 'exceptional'],
    'student': ['rob', 'maya', 'parthiv', 'tom', 'julian', 'erica']
})
df
# Out:
#          score  student
# 0  exceptional      rob
# 1      average     maya
# 2         good  parthiv
# 3         poor      tom
# 4      average   julian
# 5  exceptional    erica

# %%
df.replace(['poor', 'average', 'good', 'exceptional'], [1,2,3,4])
# Out:
#    score  student
# 0      4      rob
# 1      2     maya
# 2      3  parthiv
# 3      1      tom
# 4      2   julian
# 5      4    erica

# %% [markdown]
# # group by

# %%
df = pd.read_csv('datasets/weather_by_cities_group_by.csv')

# %%
df
# Out:
#          day      city  temperature  windspeed   event
# 0   1/1/2017  new york           32          6    Rain
# 1   1/2/2017  new york           36          7   Sunny
# 2   1/3/2017  new york           28         12    Snow
# 3   1/4/2017  new york           33          7   Sunny
# 4   1/1/2017    mumbai           90          5   Sunny
# 5   1/2/2017    mumbai           85         12     Fog
# 6   1/3/2017    mumbai           87         15     Fog
# 7   1/4/2017    mumbai           92          5    Rain
# 8   1/1/2017     paris           45         20   Sunny
# 9   1/2/2017     paris           50         13  Cloudy
# 10  1/3/2017     paris           54          8  Cloudy
# 11  1/4/2017     paris           42         10  Cloudy

# %%
g= df.groupby('city')

# %%
g

# %%
g.get_group('new york')
# Out:
#         day      city  temperature  windspeed  event
# 0  1/1/2017  new york           32          6   Rain
# 1  1/2/2017  new york           36          7  Sunny
# 2  1/3/2017  new york           28         12   Snow
# 3  1/4/2017  new york           33          7  Sunny

# %%
g.get_group('paris')
# Out:
#          day   city  temperature  windspeed   event
# 8   1/1/2017  paris           45         20   Sunny
# 9   1/2/2017  paris           50         13  Cloudy
# 10  1/3/2017  paris           54          8  Cloudy
# 11  1/4/2017  paris           42         10  Cloudy

# %%
g.get_group('new york')

# %%
for data in g:
    print(data)
# Out:
# ('mumbai',         day    city  temperature  windspeed  event
# 4  1/1/2017  mumbai           90          5  Sunny
# 5  1/2/2017  mumbai           85         12    Fog
# 6  1/3/2017  mumbai           87         15    Fog
# 7  1/4/2017  mumbai           92          5   Rain)
# ('new york',         day      city  temperature  windspeed  event
# 0  1/1/2017  new york           32          6   Rain
# 1  1/2/2017  new york           36          7  Sunny
# 2  1/3/2017  new york           28         12   Snow
# 3  1/4/2017  new york           33          7  Sunny)
# ('paris',          day   city  temperature  windspeed   event
# 8   1/1/2017  paris           45         20   Sunny
# 9   1/2/2017  paris           50         13  Cloudy
# 10  1/3/2017  paris           54          8  Cloudy
# 11  1/4/2017  paris           42         10  Cloudy)

# %%
g.max()
# Out:
#                day  temperature  windspeed  event
# city
# mumbai    1/4/2017           92         15  Sunny
# new york  1/4/2017           36         12  Sunny
# paris     1/4/2017           54         20  Sunny

# %%
g.min()
# Out:
#                day  temperature  windspeed   event
# city
# mumbai    1/1/2017           85          5     Fog
# new york  1/1/2017           28          6    Rain
# paris     1/1/2017           42          8  Cloudy
